# %% [markdown]
# # Here you can easily see some of the optimal trajectories of the database.

# %% [markdown]
# Imports

# %%
from matplotlib import pyplot as plt
import glob
import os
import numpy as np
from matplotlib import pyplot as plt
import matplotlib

# %% [markdown]
# Get the current path

# %%
path = os.path.abspath(os.getcwd())

# %% [markdown]
# Get all the files in the database directory (here called /opt_traj)

# %%
files = glob.glob(path+'/opt_traj/'+'*.dat') # Get all .dat files in the folder

# %% [markdown]
# Let's plot a trajectory

# %%
file_number = 0
fig, axs = plt.subplots(2,3,figsize=(11,7), tight_layout=True)



for file_number in range(len(files)):
    data = np.loadtxt(files[file_number])
    # matplotlib.rcParams['text.usetex'] = True # habilitando tex 

    # # Get the q value 
    # start = files[file_number].find('q_') + 2
    # end = files[file_number].find('r_', start)
    # q_value = files[file_number][start:end]

    # # get the r value 
    # start = files[file_number].find('r_') + 2
    # end = files[file_number].find('x1i_', start)
    # r_value = files[file_number][start:end]
    

    axs[0,0].plot(data[:,0],data[:,1])
    axs[0,0].set_xlabel(r'$s$')
    axs[0,0].set_ylabel(r'$[m]$')

    axs[0,1].plot(data[:,0],data[:,2])
    axs[0,1].set_xlabel(r'$s$')
    axs[0,1].set_ylabel(r'$[m/s]$')

    axs[1,0].plot(data[:,0],data[:,3]*180/np.pi)
    axs[1,0].set_xlabel(r'$s$')
    axs[1,0].set_ylabel(r'$[^\circ]$')

    axs[1,1].plot(data[:,0],data[:,4]*180/np.pi)
    axs[1,1].set_xlabel(r'$s$')
    axs[1,1].set_ylabel(r'$[^\circ/s]$')

    axs[0,2].plot(data[:,0],data[:,5])
    axs[0,2].set_xlabel(r'$s$')
    axs[0,2].set_ylabel(r'$[N]$')

    # axs[1,2].plot([0],[0], label = 'Trajetória número: ' + str(file_number))

    axs[1,2].legend(loc='upper left')
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 5
#       1 file_number = 0
#       4 for file_number in range(len(files)):
# ----> 5     fig, axs = plt.subplots(2,3,figsize=(11,7), tight_layout=True)
#       6     data = np.loadtxt(files[file_number])
#       7     # matplotlib.rcParams['text.usetex'] = True # habilitando tex
#       8
#       9     # # Get the q value
#    (...)
#      16     # end = files[file_number].find('x1i_', start)
#      17     # r_value = files[file_number][start:end]
#
# File /mnt/e0e91479-681a-494e-8442-ea1d3ae8c6e7/Documentos/2-Mestrado/optdnn/venv/lib/python3.8/site-packages/matplotlib/pyplot.py:1443, in subplots(nrows, ncols, sharex, sharey, squeeze, width_ratios, height_ratios, subplot_kw, gridspec_kw, **fig_kw)
#    1299 """
#    1300 Create a figure and a set of subplots.
#    1301
#    (...)
#    1440
#    1441 """
#    1442 fig = figure(**fig_kw)
# -> 1443 axs = fig.subplots(nrows=nrows, ncols=ncols, sharex=sharex, sharey=sharey,
#    1444                    squeeze=squeeze, subplot_kw=subplot_kw,
#    1445                    gridspec_kw=gridspec_kw, height_ratios=height_ratios,
#    1446                    width_ratios=width_ratios)
#    1447 return fig, axs
#
# File /mnt/e0e91479-681a-494e-8442-ea1d3ae8c6e7/Documentos/2-Mestrado/optdnn/venv/lib/python3.8/site-packages/matplotlib/figure.py:894, in FigureBase.subplots(self, nrows, ncols, sharex, sharey, squeeze, width_ratios, height_ratios, subplot_kw, gridspec_kw)
#     891     gridspec_kw['width_ratios'] = width_ratios
#     893 gs = self.add_gridspec(nrows, ncols, figure=self, **gridspec_kw)
# --> 894 axs = gs.subplots(sharex=sharex, sharey=sharey, squeeze=squeeze,
#     895                   subplot_kw=subplot_kw)
#     896 return axs
#
# File /mnt/e0e91479-681a-494e-8442-ea1d3ae8c6e7/Documentos/2-Mestrado/optdnn/venv/lib/python3.8/site-packages/matplotlib/gridspec.py:308, in GridSpecBase.subplots(self, sharex, sharey, squeeze, subplot_kw)
#     306         subplot_kw["sharex"] = shared_with[sharex]
#     307         subplot_kw["sharey"] = shared_with[sharey]
# --> 308         axarr[row, col] = figure.add_subplot(
#     309             self[row, col], **subplot_kw)
#     311 # turn off redundant tick labeling
#     312 if sharex in ["col", "all"]:
#
# File /mnt/e0e91479-681a-494e-8442-ea1d3ae8c6e7/Documentos/2-Mestrado/optdnn/venv/lib/python3.8/site-packages/matplotlib/figure.py:745, in FigureBase.add_subplot(self, *args, **kwargs)
#     742         args = tuple(map(int, str(args[0])))
#     743     projection_class, pkw = self._process_projection_requirements(
#     744         *args, **kwargs)
# --> 745     ax = subplot_class_factory(projection_class)(self, *args, **pkw)
#     746     key = (projection_class, pkw)
#     747 return self._add_axes_internal(ax, key)
#
# File /mnt/e0e91479-681a-494e-8442-ea1d3ae8c6e7/Documentos/2-Mestrado/optdnn/venv/lib/python3.8/site-packages/matplotlib/axes/_subplots.py:34, in SubplotBase.__init__(self, fig, *args, **kwargs)
#      15 """
#      16 Parameters
#      17 ----------
#    (...)
#      31     Keyword arguments are passed to the Axes (sub)class constructor.
#      32 """
#      33 # _axes_class is set in the subplot_class_factory
# ---> 34 self._axes_class.__init__(self, fig, [0, 0, 1, 1], **kwargs)
#      35 # This will also update the axes position.
#      36 self.set_subplotspec(SubplotSpec._from_subplot_args(fig, args))
#
# File /mnt/e0e91479-681a-494e-8442-ea1d3ae8c6e7/Documentos/2-Mestrado/optdnn/venv/lib/python3.8/site-packages/matplotlib/axes/_base.py:653, in _AxesBase.__init__(self, fig, rect, facecolor, frameon, sharex, sharey, label, xscale, yscale, box_aspect, **kwargs)
#     650 self.set_axisbelow(mpl.rcParams['axes.axisbelow'])
#     652 self._rasterization_zorder = None
# --> 653 self.clear()
#     655 # funcs used to format x and y - fall back on major formatters
#     656 self.fmt_xdata = None
#
# File /mnt/e0e91479-681a-494e-8442-ea1d3ae8c6e7/Documentos/2-Mestrado/optdnn/venv/lib/python3.8/site-packages/matplotlib/axes/_base.py:1348, in _AxesBase.clear(self)
#    1346     self.cla()
#    1347 else:
# -> 1348     self.__clear()
#
# File /mnt/e0e91479-681a-494e-8442-ea1d3ae8c6e7/Documentos/2-Mestrado/optdnn/venv/lib/python3.8/site-packages/matplotlib/axes/_base.py:1276, in _AxesBase.__clear(self)
#    1273 self.legend_ = None
#    1274 self.containers = []
# -> 1276 self.grid(False)  # Disable grid on init to use rcParameter
#    1277 self.grid(self._gridOn, which=mpl.rcParams['axes.grid.which'],
#    1278           axis=mpl.rcParams['axes.grid.axis'])
#    1279 props = font_manager.FontProperties(
#    1280     size=mpl.rcParams['axes.titlesize'],
#    1281     weight=mpl.rcParams['axes.titleweight'])
#
# File /mnt/e0e91479-681a-494e-8442-ea1d3ae8c6e7/Documentos/2-Mestrado/optdnn/venv/lib/python3.8/site-packages/matplotlib/_api/deprecation.py:297, in rename_parameter.<locals>.wrapper(*args, **kwargs)
#     292     warn_deprecated(
#     293         since, message=f"The {old!r} parameter of {func.__name__}() "
#     294         f"has been renamed {new!r} since Matplotlib {since}; support "
#     295         f"for the old name will be dropped %(removal)s.")
#     296     kwargs[new] = kwargs.pop(old)
# --> 297 return func(*args, **kwargs)
#
# File /mnt/e0e91479-681a-494e-8442-ea1d3ae8c6e7/Documentos/2-Mestrado/optdnn/venv/lib/python3.8/site-packages/matplotlib/axes/_base.py:3238, in _AxesBase.grid(self, visible, which, axis, **kwargs)
#    3236 _api.check_in_list(['x', 'y', 'both'], axis=axis)
#    3237 if axis in ['x', 'both']:
# -> 3238     self.xaxis.grid(visible, which=which, **kwargs)
#    3239 if axis in ['y', 'both']:
#    3240     self.yaxis.grid(visible, which=which, **kwargs)
#
# File /mnt/e0e91479-681a-494e-8442-ea1d3ae8c6e7/Documentos/2-Mestrado/optdnn/venv/lib/python3.8/site-packages/matplotlib/_api/deprecation.py:297, in rename_parameter.<locals>.wrapper(*args, **kwargs)
#     292     warn_deprecated(
#     293         since, message=f"The {old!r} parameter of {func.__name__}() "
#     294         f"has been renamed {new!r} since Matplotlib {since}; support "
#     295         f"for the old name will be dropped %(removal)s.")
#     296     kwargs[new] = kwargs.pop(old)
# --> 297 return func(*args, **kwargs)
#
# File /mnt/e0e91479-681a-494e-8442-ea1d3ae8c6e7/Documentos/2-Mestrado/optdnn/venv/lib/python3.8/site-packages/matplotlib/axis.py:1593, in Axis.grid(self, visible, which, **kwargs)
#    1590 if which in ['major', 'both']:
#    1591     gridkw['gridOn'] = (not self._major_tick_kw['gridOn']
#    1592                         if visible is None else visible)
# -> 1593     self.set_tick_params(which='major', **gridkw)
#    1594 self.stale = True
#
# File /mnt/e0e91479-681a-494e-8442-ea1d3ae8c6e7/Documentos/2-Mestrado/optdnn/venv/lib/python3.8/site-packages/matplotlib/axis.py:940, in Axis.set_tick_params(self, which, reset, **kwargs)
#     938 if which in ['major', 'both']:
#     939     self._major_tick_kw.update(kwtrans)
# --> 940     for tick in self.majorTicks:
#     941         tick._apply_params(**kwtrans)
#     942 if which in ['minor', 'both']:
#
# File /mnt/e0e91479-681a-494e-8442-ea1d3ae8c6e7/Documentos/2-Mestrado/optdnn/venv/lib/python3.8/site-packages/matplotlib/axis.py:600, in _LazyTickList.__get__(self, instance, cls)
#     598     instance.majorTicks = []
#     599     tick = instance._get_tick(major=True)
# --> 600     instance.majorTicks.append(tick)
#     601     return instance.majorTicks
#     602 else:
#
# File /mnt/e0e91479-681a-494e-8442-ea1d3ae8c6e7/Documentos/2-Mestrado/optdnn/venv/lib/python3.8/site-packages/matplotlib/axis.py:599, in _LazyTickList.__get__(self, instance, cls)
#     597 if self._major:
#     598     instance.majorTicks = []
# --> 599     tick = instance._get_tick(major=True)
#     600     instance.majorTicks.append(tick)
#     601     return instance.majorTicks
#
# File /mnt/e0e91479-681a-494e-8442-ea1d3ae8c6e7/Documentos/2-Mestrado/optdnn/venv/lib/python3.8/site-packages/matplotlib/axis.py:1483, in Axis._get_tick(self, major)
#    1479     raise NotImplementedError(
#    1480         f"The Axis subclass {self.__class__.__name__} must define "
#    1481         "_tick_class or reimplement _get_tick()")
#    1482 tick_kw = self._major_tick_kw if major else self._minor_tick_kw
# -> 1483 return self._tick_class(self.axes, 0, major=major, **tick_kw)
#
# File /mnt/e0e91479-681a-494e-8442-ea1d3ae8c6e7/Documentos/2-Mestrado/optdnn/venv/lib/python3.8/site-packages/matplotlib/axis.py:422, in XTick.__init__(self, *args, **kwargs)
#     421 def __init__(self, *args, **kwargs):
# --> 422     super().__init__(*args, **kwargs)
#     423     # x in data coords, y in axes coords
#     424     ax = self.axes
#
# File /mnt/e0e91479-681a-494e-8442-ea1d3ae8c6e7/Documentos/2-Mestrado/optdnn/venv/lib/python3.8/site-packages/matplotlib/axis.py:156, in Tick.__init__(self, axes, loc, size, width, color, tickdir, pad, labelsize, labelcolor, zorder, gridOn, tick1On, tick2On, label1On, label2On, major, labelrotation, grid_color, grid_linestyle, grid_linewidth, grid_alpha, **kwargs)
#     153     grid_alpha = mpl.rcParams["grid.alpha"]
#     154 grid_kw = {k[5:]: v for k, v in kwargs.items()}
# --> 156 self.tick1line = mlines.Line2D(
#     157     [], [],
#     158     color=color, linestyle="none", zorder=zorder, visible=tick1On,
#     159     markeredgecolor=color, markersize=size, markeredgewidth=width,
#     160 )
#     161 self.tick2line = mlines.Line2D(
#     162     [], [],
#     163     color=color, linestyle="none", zorder=zorder, visible=tick2On,
#     164     markeredgecolor=color, markersize=size, markeredgewidth=width,
#     165 )
#     166 self.gridline = mlines.Line2D(
#     167     [], [],
#     168     color=grid_color, alpha=grid_alpha, visible=gridOn,
#     169     linestyle=grid_linestyle, linewidth=grid_linewidth, marker="",
#     170     **grid_kw,
#     171 )
#
# File /mnt/e0e91479-681a-494e-8442-ea1d3ae8c6e7/Documentos/2-Mestrado/optdnn/venv/lib/python3.8/site-packages/matplotlib/_api/deprecation.py:454, in make_keyword_only.<locals>.wrapper(*args, **kwargs)
#     448 if len(args) > name_idx:
#     449     warn_deprecated(
#     450         since, message="Passing the %(name)s %(obj_type)s "
#     451         "positionally is deprecated since Matplotlib %(since)s; the "
#     452         "parameter will become keyword-only %(removal)s.",
#     453         name=name, obj_type=f"parameter of {func.__name__}()")
# --> 454 return func(*args, **kwargs)
#
# File /mnt/e0e91479-681a-494e-8442-ea1d3ae8c6e7/Documentos/2-Mestrado/optdnn/venv/lib/python3.8/site-packages/matplotlib/lines.py:378, in Line2D.__init__(self, xdata, ydata, linewidth, linestyle, color, gapcolor, marker, markersize, markeredgewidth, markeredgecolor, markerfacecolor, markerfacecoloralt, fillstyle, antialiased, dash_capstyle, solid_capstyle, dash_joinstyle, solid_joinstyle, pickradius, drawstyle, markevery, **kwargs)
#     375 self._antialiased = None
#     377 self.set_markevery(markevery)
# --> 378 self.set_antialiased(antialiased)
#     379 self.set_markersize(markersize)
#     381 self._markeredgecolor = None
#
# File /mnt/e0e91479-681a-494e-8442-ea1d3ae8c6e7/Documentos/2-Mestrado/optdnn/venv/lib/python3.8/site-packages/matplotlib/lines.py:1051, in Line2D.set_antialiased(self, b)
#    1043 """
#    1044 Set whether to use antialiased rendering.
#    1045
#    (...)
#    1048 b : bool
#    1049 """
#    1050 if self._antialiased != b:
# -> 1051     self.stale = True
#    1052 self._antialiased = b
#
# File /mnt/e0e91479-681a-494e-8442-ea1d3ae8c6e7/Documentos/2-Mestrado/optdnn/venv/lib/python3.8/site-packages/matplotlib/artist.py:289, in Artist.stale(self, val)
#     283     """
#     284     Whether the artist is 'stale' and needs to be re-drawn for the output
#     285     to match the internal state of the artist.
#     286     """
#     287     return self._stale
# --> 289 @stale.setter
#     290 def stale(self, val):
#     291     self._stale = val
#     293     # if the artist is animated it does not take normal part in the
#     294     # draw stack and is not expected to be drawn as part of the normal
#     295     # draw loop (when not saving) so do not propagate this change
#
# KeyboardInterrupt:

# %%
plt.figure(figsize=(11,7))
plt.plot(data[:,0],data[:,5])
plt.grid(True)
plt.xlabel(r'$s$')
plt.ylabel(r'$[N]$')
# Out:
# Text(0, 0.5, '$[N]$')

# %%
plt.figure(figsize=(11,7))
plt.plot(data[-30:,0],data[-30:,2])
plt.grid(True)
plt.xlabel(r'$s$')
plt.ylabel(r'$[m/s]$')
# Out:
# Text(0, 0.5, '$[m/s]$')
